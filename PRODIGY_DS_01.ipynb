# %% [markdown]
# # TASK 1

# %%
# import the libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import the dataset
df=pd.read_csv("C:/Users/Hp/Downloads/archive (2)/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#identifying categorical variables
categorical_columns = df.select_dtypes(include=['object']).columns

# displaying/printing the categorical variables
print("Categorical variables: ")
for column in categorical_columns:
    print(column)
# Out:
# Categorical variables:
# gender
# race/ethnicity
# parental level of education
# lunch
# test preparation course

# %%
# Display the percentage distribution for each categorical variable
for column in categorical_columns:
    print(f"{column.capitalize()} Distribution:")
    value_counts = df[column].value_counts(normalize=True) * 100  # Convert counts to percentages
    print(value_counts)
    print()
# Out:
# Gender Distribution:
# female    51.8
# male      48.2
# Name: gender, dtype: float64
#
# Race/ethnicity Distribution:
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: race/ethnicity, dtype: float64
#
# Parental level of education Distribution:
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: parental level of education, dtype: float64
#
# Lunch Distribution:
# standard        64.5
# free/reduced    35.5
# Name: lunch, dtype: float64
#
# Test preparation course Distribution:
# none         64.2
# completed    35.8
# Name: test preparation course, dtype: float64

# %% [markdown]
# ### visualisation

# %%
# creating a bargraph for each categorical variable

# %%
# gender distribution
plt.figure(figsize=(8,5))
gender_counts=df['gender'].value_counts()
gender_counts.plot(kind='bar',color=['pink','blue'])
plt.title("Gender distribution")
plt.xlabel("Gender")
plt.ylabel("counts")
plt.xticks(rotation=0)
plt.show()
gender_counts
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# ethnicity distribution
plt.figure(figsize=(8,5))
race_counts=df['race/ethnicity'].value_counts()
race_counts.plot(kind='bar',color=['red'])
plt.title("Ethnicity distribution")
plt.xlabel("Ethnicity")
plt.ylabel("counts")
plt.xticks(rotation=0)
plt.show()
race_counts
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
#Parental level of education
plt.figure(figsize=(8,5))
ple_counts=df['parental level of education'].value_counts()
ple_counts.plot(kind='bar')
plt.title("Parental level of education distribution")
plt.xlabel("Parental level of education")
plt.ylabel("counts")
plt.xticks(rotation=90)
plt.show()
ple_counts
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
# lunch distribution
plt.figure(figsize=(8,5))
lunch_counts=df['lunch'].value_counts()
lunch_counts.plot(kind='bar',color='green')
plt.title("lunch distribution")
plt.xlabel("lunch")
plt.ylabel("counts")
plt.xticks(rotation=0)
plt.show()
lunch_counts
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
plt.figure(figsize=(8, 5))
test_prep_counts = df['test preparation course'].value_counts()
test_prep_counts.plot(kind='bar', color=['red', 'cyan'])
plt.title('Test Preparation Course Distribution')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
test_prep_counts
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
# continuous variables
continuous_columns = df.select_dtypes(include=['int64']).columns

# displaying/printing the continuous variables
print("continuous variables: ")
for column in continuous_columns:
    print(column)
# Out:
# continuous variables:
# math score
# reading score
# writing score

# %%
# plotting histogram for continuous variables
for column in continuous_columns:
    plt.figure(figsize=(8, 5))
    plt.hist(df[column], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column.replace(" ", "/").capitalize()}')
    plt.xlabel(column.capitalize())
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
